# %%
import skimage
import matplotlib.pyplot as plt

#!pip install skimage #to install the package 'skimage'

# %%
# %matplotlib inline

# %%
from skimage import io  #to read input and output

# %%
from skimage import data   #set of images in data

# %%
img=io.imread('pup.jpg')

# %%
plt.imshow(img)

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np

# Load your image (replace 'your_image.png' with your image file)
img = plt.imread('pup.jpg')

contrast_factor = 100  # Increase for higher contrast
brightness_factor = 100  # Increase for higher brightness
cmap = mcolors.LinearSegmentedColormap.from_list(
    'custom_cmap', image / brightness_factor, N=256)

# Display the image with the custom colormap
plt.imshow(image, cmap=cmap)

plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 10
#       8 contrast_factor = 100  # Increase for higher contrast
#       9 brightness_factor = 100  # Increase for higher brightness
# ---> 10 cmap = mcolors.LinearSegmentedColormap.from_list(
#      11     'custom_cmap', image / brightness_factor, N=256)
#      13 # Display the image with the custom colormap
#      14 plt.imshow(image, cmap=cmap)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\colors.py:1056, in LinearSegmentedColormap.from_list(name, colors, N, gamma)
#    1053 else:
#    1054     vals = np.linspace(0, 1, len(colors))
# -> 1056 r, g, b, a = to_rgba_array(colors).T
#    1057 cdict = {
#    1058     "red": np.column_stack([vals, r, r]),
#    1059     "green": np.column_stack([vals, g, g]),
#    1060     "blue": np.column_stack([vals, b, b]),
# ...

# %%
img
# Out:
# array([[[ 55,  62,  29],
#         [ 56,  63,  30],
#         [ 57,  64,  31],
#         ...,
#         [149, 143, 119],
#         [149, 143, 119],
#         [150, 144, 120]],
#
#        [[ 55,  62,  29],
#         [ 56,  63,  30],
#         [ 57,  64,  31],
#         ...,
#         [149, 143, 119],
#         [149, 143, 119],
#         [149, 143, 119]],
#
#        [[ 55,  62,  29],
#         [ 55,  62,  29],
#         [ 57,  64,  31],
#         ...,
#         [149, 143, 119],
#         [149, 143, 119],
#         [149, 143, 119]],
#
#        ...,
#
#        [[127, 100,  55],
#         [127, 100,  55],
#         [126,  99,  54],
#         ...,
#         [ 70,  56,  30],
#         [ 89,  75,  49],
#         [ 81,  67,  40]],
#
#        [[124,  96,  49],
#         [125,  97,  50],
#         [126,  98,  51],
#         ...,
#         [ 71,  55,  29],
#         [ 77,  61,  35],
#         [ 74,  58,  32]],
#
#        [[122,  94,  46],
#         [124,  96,  48],
#         [126,  98,  50],
# ...

# %%
type(img) #to see the type
# Out:
# numpy.ndarray

# %%
img.shape  #to check how many rows and columns in an image
# Out:
# (1000, 1600, 3)

# %%
camera=data.camera()  #importing a image from data

# %%
camera
# Out:
# array([[200, 200, 200, ..., 189, 190, 190],
#        [200, 199, 199, ..., 190, 190, 190],
#        [199, 199, 199, ..., 190, 190, 190],
#        ...,
#        [ 25,  25,  27, ..., 139, 122, 147],
#        [ 25,  25,  26, ..., 158, 141, 168],
#        [ 25,  25,  27, ..., 151, 152, 149]], dtype=uint8)

# %%
plt.imshow(camera)
camera.shape
# Out:
# (512, 512)

# %%
type(camera)
# Out:
# numpy.ndarray

# %%
camera.size
# Out:
# 262144

# %%
plt.imshow(camera,'gray')  #displays the image in gray

# %%
camera.max()
# Out:
# 255

# %%
plt.imshow(img[:,:,1])  #channel(0-red,1-green,2-blue)

# %%
plt.imshow(img[:,:,0])  #channel(0-red,1-green,2-blue)

# %%
plt.imshow(img[:,:,2])   #channel(0-red,1-green,2-blue)

# %%
#Threshhold
camera=data.camera()
mask=camera>150
camera[mask]=255
plt.imshow(camera)

# %%
plt.imshow(chelsea)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 plt.imshow(chelsea)
#
# NameError: name 'chelsea' is not defined
