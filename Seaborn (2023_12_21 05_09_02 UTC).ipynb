# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
mtcars=pd.read_csv('C:/Users/Rohitha Manne/Python Programming/mtcars.csv')
mtcars.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
mtcars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   model   32 non-null     object
#  1   mpg     32 non-null     float64
#  2   cyl     32 non-null     int64
#  3   disp    32 non-null     float64
#  4   hp      32 non-null     int64
#  5   drat    32 non-null     float64
#  6   wt      32 non-null     float64
#  7   qsec    32 non-null     float64
#  8   vs      32 non-null     int64
#  9   am      32 non-null     int64
#  10  gear    32 non-null     int64
#  11  carb    32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
mtcars.shape
# Out:
# (32, 12)

# %%
res = sns.barplot(mtcars)

# %%
res1=sns.barplot(x=mtcars['cyl'],y=mtcars['carb'])
plt.show()

# %%
res1=sns.barplot(x='cyl', y='carb', data=mtcars)
plt.show()

# %%
res = sns.barplot(x=mtcars['cyl'],y=mtcars['carb'],color='yellow')

# %%
res=sns.barplot(x=mtcars['gear'],y=mtcars['hp'],palette='rocket')

# %%
sns.countplot(x='gear',data=mtcars,palette="Set1")
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2]), [Text(0, 0, '3'), Text(1, 0, '4'), Text(2, 0, '5')])

# %%
sns.countplot(x='carb',data=mtcars,palette="pastel")
# Out:
# <Axes: xlabel='carb', ylabel='count'>

# %%
sns.countplot(y='gear',data=mtcars,palette='colorblind')
# Out:
# <Axes: xlabel='count', ylabel='gear'>

# %%
sns.countplot(x='cyl',data=mtcars,palette="Set3")
# Out:
# <Axes: xlabel='cyl', ylabel='count'>

# %%
sns.countplot(x='cyl',data=mtcars,palette="deep")
# Out:
# <Axes: xlabel='cyl', ylabel='count'>

# %%
sns.countplot(x='gear',hue='cyl',data=mtcars,palette='pastel')
# Out:
# <Axes: xlabel='gear', ylabel='count'>

# %%
sns.distplot(mtcars.mpg,bins=20,color='g')
# Out:
# C:\Users\Rohitha Manne\AppData\Local\Temp\ipykernel_7052\1996017467.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(mtcars.mpg,bins=20,color='g')
# <Axes: xlabel='mpg', ylabel='Density'>

# %%
sns.displot(mtcars.mpg,bins=50,color='g')

# %%
sns.heatmap(mtcars.corr(),cbar=True,linewidths=5)
# Out:
# C:\Users\Rohitha Manne\AppData\Local\Temp\ipykernel_7052\3818370307.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(mtcars.corr(),cbar=True,linewidths=5)
# <Axes: >

# %%
sns.heatmap(mtcars.corr(numeric_only=True), cbar=True, linewidths=2)
# Out:
# <Axes: >

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(data=iris)
# Out:
# <Axes: >

# %%
sns.scatterplot(x='sepal_length',y='petal_length',data=iris,hue='sepal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris,hue='species')

# %%
sns.pairplot(iris,hue='species',palette='dark')

# %%
sns.lmplot(x='sepal_length',y='sepal_width',data=iris)

# %%
sns.lmplot(x='petal_length',y='petal_width',data=iris,hue='species',markers=['o','*','^'])

# %%
sns.boxplot(x='species',y='petal_length',data=iris)
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
mtcars
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
sns.boxplot(x='cyl',y='wt',data=mtcars)
# Out:
# <Axes: xlabel='cyl', ylabel='wt'>

# %%
import plotly.express as px
#df = px.data.gapminder()
fig = px.scatter(x='sepal_length',y='petal_length',
                 
	         size="pop", color="continent",log_x=True, size_max=90)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 3
#       1 import plotly.express as px
#       2 #df = px.data.gapminder()
# ----> 3 fig = px.scatter(x='sepal_length',y='petal_length',
#       4
#       5 	         size="pop", color="continent",log_x=True, size_max=90)
#       6 fig.show()
#
# ...

# %%
#creating our own function
def greet_user1():
    print("hi")
    print("welcome")
print('start')
greet_user1()
print('finish')
# Out:
# start
# hi
# welcome
# finish

# %%
#we can add parameters to the functions
def greet_user(name):
    print(f'Hi {name}!')
    print('welcome')

# %%
greet_user('john')
# Out:
# Hi john!
# welcome

# %%
greet_user1()
# Out:
# hi
# welcome

# %%
greet_user('dog')
# Out:
# Hi dog!
# welcome

# %%
def greet_user2(first_name,last_name):
    print(f'Hi {first_name} {last_name}!')
    print('welcome')

# %%
greet_user2('rajesh','kumar' )
# Out:
# Hi rajesh kumar!
# welcome

# %%
def greet_user3(first_name='Ram',last_name='Kumar'):
    print(f'Hi {first_name} {last_name}!')
    print('welcome')

# %%
greet_user3()
# Out:
# Hi Ram Kumar!
# welcome

# %%
#return statement-returns the number outside the function
#by default all functions in the python will return none

def square(number):
    return number*number

# %%
square(3)
# Out:
# 9

# %%
print('0')
# Out:
# 0

# %%
#Exceptions
#exit code 0 means success
#exit code 1 or any number is error
#if error value error displays

try:
    age=int(input('age: '))
    print(age)
except ValueError:
    print('Please enter integer')
# Out:
# age:
# Please enter integer

# %%
#program
try:
    age=int(input('age: '))
    income=20000
    risk=income/age
    print(risk)
#except ValueError:
 #   print("invalid value")
#except ZeroDivisionError:
#    print("do no give 0 as an input")
except (ValueError,ZeroDivisionError):
    print('Invalid input')
# Out:
# age:
# Invalid input

# %%
20000/12
# Out:
# 1666.6666666666667

# %%
def greet_user(): 
    me=input("name:") 
    print(f'Hi {me}!') 
    print('welcome')
print("start")
greet_user()
print('stop')
# Out:
# start
# name:
# Hi !
# welcome
# stop

# %%
greet_user()
# Out:
# name:
# Hi !
# welcome

# %%
class Snake:
    pass
snake=Snake()
print(snake)

# %%
class snake:
    name='python'    #class with attribute

# %%
snake()

# %%
prog=snake()
print(prog.name)
# Out:
# python

# %%
class Rohitha:
    designation='Student'
    
    def change_designation(self,new_designation):  #use self only while defining
        self.designation=new_designation

# %%
stud1=Rohitha()
print(stud1.designation)
# Out:
# Student

# %%
print(stud1.designation)
stud1.change_designation("Placecomm member")   #no need to give self keyword or variable for it
print(stud1.designation)
# Out:
# Student
# Placecomm member

# %%
class stud:
    def __init__(self,desgn):
        self.desgn=desgn
        
    def change_desgn(self,new_desgn):
        self.desgn=new_desgn

# %%
stud.mro()
# Out:
# [__main__.stud, object]

# %%
Rohitha_Sai = stud('student')

# %%
awc=stud('Volunteer')

# %%
print(Rohitha_Sai.desgn)
# Out:
# student

# %%
print(awc.desgn)
# Out:
# Volunteer

# %%
awc.change_desgn("Executive")
print(awc.desgn)
# Out:
# Executive

# %%
class Point:
    def __init__(self,x,y):
        self.x=x
        self.y=y
        
    def new_values(self,new_x,new_y):
        self.x=new_x
        self.y=new_y
        
    def move(self):
        print("move")
        
    def draw(self):
        print("draw")

point= Point(10,20)
print(point.x)
# Out:
# 10

# %%
point.new_values(55,65)
print(point.x)
# Out:
# 55

# %%
class Person1:
    def __init__(self):
        
        self.name=input("please enter your name:  ")
        #self.name=name
        
    def talk(self):
        print(f'Hi,I am {self.name}')

# %%
me=Person1()
print(me.name)
# Out:
# please enter your name:

# %%
class Rectangle:
    def __init__(self, length, breadth, unit_cost=0):
        self. length = length
        self.breadth = breadth
        self.unit_cost = unit_cost
    def get_perimeter (self):
        return 2 * (self.length + self.breadth)
    def get_area(self):
        return self.length * self.breadth 
    def calculate_cost(self):
        area = self.get_area()
        return area * self.unit_cost
# breadth = 120 cm, length = 160 cm, 1 cm^2 = Rs 2000
r = Rectangle(160, 120, 2000)
print("Area of Rectangle: %s cm^2" % (r.get_area()))
print("Cost of rectangular field: Rs. %s " %(r. calculate_cost ()))
# Out:
# Area of Rectangle: 19200 cm^2
# Cost of rectangular field: Rs. 38400000

# %%
#inheritance

class Mammal:
    def walk(Self):
        print("walk")

class Dog(Mammal):
    def bark(self):
        print('bark')
        #pass

class Cat(Mammal):
    pass

dog1=Dog()
dog1.bark()
# Out:
# bark

# %%
#choices with random
import random
members=['J','M','B']
name=random.choice(members)
print(name)
# Out:
# M

# %%
#roll a dice
import random
class Dice:
    def roll(self):
        throw=random.randint(1,6)
        second_throw=random.randint(1,6)
        if throw==6:
            return throw,second_throw
        return throw
dice=Dice()
print(dice.roll())
# Out:
# 4

# %%
host_addresses = {"router": "192.168.1.1", "localhost": "127.0.0.1", "google": "8.8.8.8"}
host_addresses.keys()
# Out:
# dict_keys(['router', 'localhost', 'google'])

# %%
colors
# Out:
# UsageError: %colors: you must specify a color scheme. See '%colors?'
