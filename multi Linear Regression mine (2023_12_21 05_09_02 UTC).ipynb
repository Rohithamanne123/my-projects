# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random #to generate random numbers
import datetime #for date functions
import math #for math functions
# %matplotlib inline
df=pd.read_csv('C:/Users/Rohitha Manne/Python Programming/height_weight.csv')

# %%
df
# Out:
#       Height  Weight
# 0     187.57  109.72
# 1     174.71   73.62
# 2     188.24   96.50
# 3     182.20   99.81
# 4     177.50   93.60
# ...      ...     ...
# 9995  168.08   62.04
# 9996  170.35   77.50
# 9997  162.22   58.28
# 9998  175.35   74.32
# 9999  157.34   51.55
#
# [10000 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# Height    46
# Weight     0
# dtype: int64

# %%
df = df.fillna(df.mean())

# %%
df.isnull().sum()
# Out:
# Height    0
# Weight    0
# dtype: int64

# %%
x=df.iloc[:,0:1].values
y=df.iloc[:,1:].values
print(x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x=df.iloc[:,0:1].values
#       2 y=df.iloc[:,1:].values
#       3 print(x,y)
#
# NameError: name 'df' is not defined

# %%
#split the data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.30,random_state=1000)

# %%
#build the model
from sklearn.linear_model import LinearRegression
regr=LinearRegression()
regr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = regr.predict(x_train)
y_test_pred = regr.predict(x_test)

# %%
y_train_pred
# Out:
# array([ 98.72445546, 101.69900006,  54.0647812 , ...,  78.42837673,
#         94.32489647,  66.39184742])

# %%
y_test_pred
# Out:
# array([72.8389999 , 80.18543331, 78.16551   , ..., 89.7454813 ,
#        78.05482927, 58.71337183])

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
#mean squared error
print('MSE train: %.3f,test: %.3f'%(mean_squared_error(y_train,y_train_pred),
                                    mean_squared_error(y_test,y_test_pred)))
# Out:
# MSE train: 31.238,test: 32.120

# %%
#r-squared
print('R^2 train: %2.3f,test:%2.3f'%(r2_score(y_train,y_train_pred),r2_score(y_test,y_test_pred)))
# Out:
# R^2 train: 0.855,test:0.842

# %%
r2_score(y_test,y_test_pred)
# Out:
# 0.8419317079471705

# %%
#visualize
plt.title('Linear Regression')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,y_train_pred,color='blue')

# %%
my_ht=[[173]]
my_wt_pred=regr.predict(my_ht)
print(my_wt_pred)
# Out:
# [79.43046397]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random #to generate random numbers
import datetime #for date functions
import math #for math functions
# %matplotlib inline
df=pd.read_csv('C:/Users/Rohitha Manne/Python Programming/50_startups.csv')

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend        City     Profit
# 0   165349.20       136897.80        471784.10     Chennai  192261.83
# 1   162597.70       151377.59        443898.53     Madurai  191792.06
# 2   153441.51       101145.55        407934.54  Coimbatore  191050.39
# 3   144372.41       118671.85        383199.62     Chennai  182901.99
# 4   142107.34        91391.77        366168.42  Coimbatore  166187.94
# 5   131876.90        99814.71        362861.36     Chennai  156991.12
# 6   134615.46       147198.87        127716.82     Madurai  156122.51
# 7   130298.13       145530.06        323876.68  Coimbatore  155752.60
# 8   120542.52       148718.95        311613.29     Chennai  152211.77
# 9   123334.88       108679.17        304981.62     Madurai  149759.96
# 10  101913.08       110594.11        229160.95  Coimbatore  146121.95
# 11  100671.96        91790.61        249744.55     Madurai  144259.40
# ...

# %%
df.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# City               0
# Profit             0
# dtype: int64

# %%
df.iloc[:,0:3]
# Out:
#     R&D Spend  Administration  Marketing Spend
# 0   165349.20       136897.80        471784.10
# 1   162597.70       151377.59        443898.53
# 2   153441.51       101145.55        407934.54
# 3   144372.41       118671.85        383199.62
# 4   142107.34        91391.77        366168.42
# 5   131876.90        99814.71        362861.36
# 6   134615.46       147198.87        127716.82
# 7   130298.13       145530.06        323876.68
# 8   120542.52       148718.95        311613.29
# 9   123334.88       108679.17        304981.62
# 10  101913.08       110594.11        229160.95
# 11  100671.96        91790.61        249744.55
# 12   93863.75       127320.38        249839.44
# 13   91992.39       135495.07        252664.93
# 14  119943.24       156547.42        256512.92
# 15  114523.61       122616.84        261776.23
# 16   78013.11       121597.55        264346.06
# 17   94657.16       145077.58        282574.31
# 18   91749.16       114175.79        294919.57
# ...

# %%
chen=df[df['City']=='Chennai']
print(chen)
# Out:
#     R&D Spend  Administration  Marketing Spend     City     Profit
# 0   165349.20       136897.80        471784.10  Chennai  192261.83
# 3   144372.41       118671.85        383199.62  Chennai  182901.99
# 5   131876.90        99814.71        362861.36  Chennai  156991.12
# 8   120542.52       148718.95        311613.29  Chennai  152211.77
# 15  114523.61       122616.84        261776.23  Chennai  129917.04
# 17   94657.16       145077.58        282574.31  Chennai  125370.37
# 19   86419.70       153514.11             0.00  Chennai  122776.86
# 21   78389.47       153773.43        299737.29  Chennai  111313.02
# 24   77044.01        99281.34        140574.81  Chennai  108552.04
# 27   72107.60       127864.55        353183.81  Chennai  105008.31
# 29   65605.48       153032.06        107138.38  Chennai  101004.64
# 31   61136.38       152701.92         88218.23  Chennai   97483.56
# 35   46014.02        85047.44        205517.64  Chennai   96479.51
# ...

# %%
mad=df[df['City']=='Madurai']
print(mad)
# Out:
#     R&D Spend  Administration  Marketing Spend     City     Profit
# 1   162597.70       151377.59        443898.53  Madurai  191792.06
# 6   134615.46       147198.87        127716.82  Madurai  156122.51
# 9   123334.88       108679.17        304981.62  Madurai  149759.96
# 11  100671.96        91790.61        249744.55  Madurai  144259.40
# 13   91992.39       135495.07        252664.93  Madurai  134307.35
# 16   78013.11       121597.55        264346.06  Madurai  126992.93
# 20   76253.86       113867.30        298664.47  Madurai  118474.03
# 25   64664.71       139553.16        137962.62  Madurai  107404.34
# 32   63408.86       129219.61         46085.25  Madurai   97427.84
# 34   46426.07       157693.92        210797.67  Madurai   96712.80
# 37   44069.95        51283.14        197029.42  Madurai   89949.14
# 39   38558.51        82982.09        174999.30  Madurai   81005.76
# 40   28754.33       118546.05        172795.67  Madurai   78239.91
# ...

# %%
coim=df[df['City']=='Coimbatore']
print(coim)
# Out:
#     R&D Spend  Administration  Marketing Spend        City     Profit
# 2   153441.51       101145.55        407934.54  Coimbatore  191050.39
# 4   142107.34        91391.77        366168.42  Coimbatore  166187.94
# 7   130298.13       145530.06        323876.68  Coimbatore  155752.60
# 10  101913.08       110594.11        229160.95  Coimbatore  146121.95
# 12   93863.75       127320.38        249839.44  Coimbatore  141585.52
# 14  119943.24       156547.42        256512.92  Coimbatore  132602.65
# 18   91749.16       114175.79        294919.57  Coimbatore  124266.90
# 22   73994.56       122782.75        303319.26  Coimbatore  110352.25
# 23   67532.53       105751.03        304768.73  Coimbatore  108733.99
# 26   75328.87       144135.98        134050.07  Coimbatore  105733.54
# 28   66051.52       182645.56        118148.20  Coimbatore  103282.38
# 30   61994.48       115641.28         91131.24  Coimbatore   99937.59
# ...

# %%
x=df.iloc[:,:-1].values
y=df.iloc[:,4].values
print(x,y)
# Out:
# [[165349.2 136897.8 471784.1 'Chennai']
#  [162597.7 151377.59 443898.53 'Madurai']
#  [153441.51 101145.55 407934.54 'Coimbatore']
#  [144372.41 118671.85 383199.62 'Chennai']
#  [142107.34 91391.77 366168.42 'Coimbatore']
#  [131876.9 99814.71 362861.36 'Chennai']
#  [134615.46 147198.87 127716.82 'Madurai']
#  [130298.13 145530.06 323876.68 'Coimbatore']
#  [120542.52 148718.95 311613.29 'Chennai']
#  [123334.88 108679.17 304981.62 'Madurai']
#  [101913.08 110594.11 229160.95 'Coimbatore']
#  [100671.96 91790.61 249744.55 'Madurai']
#  [93863.75 127320.38 249839.44 'Coimbatore']
#  [91992.39 135495.07 252664.93 'Madurai']
#  [119943.24 156547.42 256512.92 'Coimbatore']
#  [114523.61 122616.84 261776.23 'Chennai']
#  [78013.11 121597.55 264346.06 'Madurai']
#  [94657.16 145077.58 282574.31 'Chennai']
#  [91749.16 114175.79 294919.57 'Coimbatore']
#  [86419.7 153514.11 0.0 'Chennai']
#  [76253.86 113867.3 298664.47 'Madurai']
#  [78389.47 153773.43 299737.29 'Chennai']
# ...

# %%
#split the data
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from sklearn.compose import ColumnTransformer
le_x = LabelEncoder()
x[:,3]=le_x.fit_transform(x[:,3])
ohe_x = ColumnTransformer(
    [('one_hot_encoder',OneHotEncoder(),[3])],
    remainder='passthrough'
)
x=np.array(ohe_x.fit_transform(x),dtype=int)

# %%
x
# Out:
# array([[     1,      0,      0, 165349, 136897, 471784],
#        [     0,      0,      1, 162597, 151377, 443898],
#        [     0,      1,      0, 153441, 101145, 407934],
#        [     1,      0,      0, 144372, 118671, 383199],
#        [     0,      1,      0, 142107,  91391, 366168],
#        [     1,      0,      0, 131876,  99814, 362861],
#        [     0,      0,      1, 134615, 147198, 127716],
#        [     0,      1,      0, 130298, 145530, 323876],
#        [     1,      0,      0, 120542, 148718, 311613],
#        [     0,      0,      1, 123334, 108679, 304981],
#        [     0,      1,      0, 101913, 110594, 229160],
#        [     0,      0,      1, 100671,  91790, 249744],
#        [     0,      1,      0,  93863, 127320, 249839],
#        [     0,      0,      1,  91992, 135495, 252664],
#        [     0,      1,      0, 119943, 156547, 256512],
#        [     1,      0,      0, 114523, 122616, 261776],
# ...

# %%
#split the data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.20,random_state=1000)

# %%
#build the model
from sklearn.linear_model import LinearRegression
regr=LinearRegression()
regr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = regr.predict(x_train)
y_test_pred = regr.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
#mean squared error
print('MSE train: %.3f,test: %.3f'%(mean_squared_error(y_train,y_train_pred),
                                    mean_squared_error(y_test,y_test_pred)))
# Out:
# MSE train: 31.368,test: 32.040

# %%
#r-squared
print('R^2 train: %2.3f,test:%2.3f'%(r2_score(y_train,y_train_pred),r2_score(y_test,y_test_pred)))
# Out:
# R^2 train: 0.854,test:0.843

# %%
r2_score(y_test,y_test_pred)
# Out:
# 0.8426818789466335

# %%
#visualize
plt.title('Linear Regression')
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,y_train_pred,color='blue')
